# %%
import pandas as pd
import numpy as np

# %%
district_data = pd.read_csv("../data/processed/districtAll.csv")
welcomeAnalysis = pd.read_csv("../data/processed/wellcomeAnalysis.csv")

# %%
cut_welcome = welcomeAnalysis[['latitude','longitude','num_bus_stops_within_1km','district']]

# %%
district_data.head()
# Out:
#                        district  latitude  longitude     Total  \
# 0  Central and Western District  22.28219  114.14486   87700.0
# 1                       Eastern  22.27722  114.22519  188400.0
# 2              Islands District  22.26382  113.96038   67400.0
# 3         Kowloon City District  22.32866  114.19121  146500.0
# 4                    Kwai Tsing  22.35288  114.10004  176600.0
#
#    Average household sie  Median income
# 0                    2.6        42000.0
# 1                    2.8        31500.0
# 2                    2.7        28800.0
# 3                    2.7        29700.0
# 4                    2.7        23300.0

# %%
welcomeAnalysis.head()
# Out:
#        name                                  formatted_address  \
# 0  Wellcome    84-90號 Queen's Road Central, Central, Hong Kong
# 1  wellcome  125, Metro Harbour View Plaza, 8 Fuk Lee St, T...
# 2  Wellcome                   319 Nathan Rd, Jordan, Hong Kong
# 3  Wellcome  Shop No.23, G/F, Hoi Fu Shopping Centre, 2 Hoi...
# 4  Wellcome  G/F, TG Place, 8 Shing Yip St, Kwun Tong, Hong...
#
#                       place_id  rating  user_ratings_total  \
# 0  ChIJ5b0oWHsABDQRJUwc57avQ94     3.8                 362
# 1  ChIJfzdi4rAABDQRYsiJViBAKIs     3.7                 259
# 2  ChIJG3W4guwABDQRsYiKQEyeUvU     3.6                 275
# 3  ChIJvdn9MLkABDQRbEofjcY9gsc     3.6                 215
# 4  ChIJabudQ0UBBDQRF2ggpcEzLiE     3.5                 182
#
#                                                types   latitude   longitude  \
# 0  ['supermarket', 'grocery_or_supermarket', 'sto...  22.283245  114.155105
# 1  ['supermarket', 'grocery_or_supermarket', 'sto...  22.324410  114.160454
# 2  ['supermarket', 'grocery_or_supermarket', 'sto...  22.306436  114.171362
# 3  ['supermarket', 'grocery_or_supermarket', 'sto...  22.315173  114.164415
# 4  ['supermarket', 'grocery_or_supermarket', 'sto...  22.310417  114.225745
#
#    num_bus_stops_within_1km  num_mtr_station_within_1km  \
# 0                       116                           5
# 1                       117                           6
# 2                        98                           3
# 3                        94                           5
# 4                        78                           3
#
#    num_competitor_within_1km                      district
# 0                          4  Central and Western District
# 1                         14                  Sham Shui Po
# 2                         13                 Yau Tsim Mong
# 3                         15                 Yau Tsim Mong
# 4                          4                     Kwon Tong

# %%
merged = welcomeAnalysis.merge(district_data, how='left', on='district')

# %%
merged.head()
# Out:
#        name                                  formatted_address  \
# 0  Wellcome    84-90號 Queen's Road Central, Central, Hong Kong
# 1  wellcome  125, Metro Harbour View Plaza, 8 Fuk Lee St, T...
# 2  Wellcome                   319 Nathan Rd, Jordan, Hong Kong
# 3  Wellcome  Shop No.23, G/F, Hoi Fu Shopping Centre, 2 Hoi...
# 4  Wellcome  G/F, TG Place, 8 Shing Yip St, Kwun Tong, Hong...
#
#                       place_id  rating  user_ratings_total  \
# 0  ChIJ5b0oWHsABDQRJUwc57avQ94     3.8                 362
# 1  ChIJfzdi4rAABDQRYsiJViBAKIs     3.7                 259
# 2  ChIJG3W4guwABDQRsYiKQEyeUvU     3.6                 275
# 3  ChIJvdn9MLkABDQRbEofjcY9gsc     3.6                 215
# 4  ChIJabudQ0UBBDQRF2ggpcEzLiE     3.5                 182
#
#                                                types  latitude_x  longitude_x  \
# 0  ['supermarket', 'grocery_or_supermarket', 'sto...   22.283245   114.155105
# 1  ['supermarket', 'grocery_or_supermarket', 'sto...   22.324410   114.160454
# 2  ['supermarket', 'grocery_or_supermarket', 'sto...   22.306436   114.171362
# 3  ['supermarket', 'grocery_or_supermarket', 'sto...   22.315173   114.164415
# 4  ['supermarket', 'grocery_or_supermarket', 'sto...   22.310417   114.225745
#
#    num_bus_stops_within_1km  num_mtr_station_within_1km  \
# 0                       116                           5
# 1                       117                           6
# 2                        98                           3
# 3                        94                           5
# 4                        78                           3
#
#    num_competitor_within_1km                      district  latitude_y  \
# 0                          4  Central and Western District    22.28219
# 1                         14                  Sham Shui Po    22.32989
# 2                         13                 Yau Tsim Mong    22.32105
# 3                         15                 Yau Tsim Mong    22.32105
# 4                          4                     Kwon Tong    22.31326
#
#    longitude_y     Total  Average household sie  Median income
# 0    114.14486   87700.0                    2.6        42000.0
# 1    114.16250  164700.0                    2.6        22000.0
# 2    114.17261  123600.0                    2.5        27900.0
# 3    114.17261  123600.0                    2.5        27900.0
# 4    114.22581  247400.0                    2.7        22200.0

# %%
district_shop = merged.groupby('district').count()[['latitude_x']]
district_shop.rename(columns={"latitude": "shop_count_in_district"},inplace=True)
# district_shop

# %%
merged1 = merged.merge(district_shop, how='left',on = 'district')

# %%
merged1.head()
# Out:
#        name                                  formatted_address  \
# 0  Wellcome    84-90號 Queen's Road Central, Central, Hong Kong
# 1  wellcome  125, Metro Harbour View Plaza, 8 Fuk Lee St, T...
# 2  Wellcome                   319 Nathan Rd, Jordan, Hong Kong
# 3  Wellcome  Shop No.23, G/F, Hoi Fu Shopping Centre, 2 Hoi...
# 4  Wellcome  G/F, TG Place, 8 Shing Yip St, Kwun Tong, Hong...
#
#                       place_id  rating  user_ratings_total  \
# 0  ChIJ5b0oWHsABDQRJUwc57avQ94     3.8                 362
# 1  ChIJfzdi4rAABDQRYsiJViBAKIs     3.7                 259
# 2  ChIJG3W4guwABDQRsYiKQEyeUvU     3.6                 275
# 3  ChIJvdn9MLkABDQRbEofjcY9gsc     3.6                 215
# 4  ChIJabudQ0UBBDQRF2ggpcEzLiE     3.5                 182
#
#                                                types  latitude_x_x  \
# 0  ['supermarket', 'grocery_or_supermarket', 'sto...     22.283245
# 1  ['supermarket', 'grocery_or_supermarket', 'sto...     22.324410
# 2  ['supermarket', 'grocery_or_supermarket', 'sto...     22.306436
# 3  ['supermarket', 'grocery_or_supermarket', 'sto...     22.315173
# 4  ['supermarket', 'grocery_or_supermarket', 'sto...     22.310417
#
#    longitude_x  num_bus_stops_within_1km  num_mtr_station_within_1km  \
# 0   114.155105                       116                           5
# 1   114.160454                       117                           6
# 2   114.171362                        98                           3
# 3   114.164415                        94                           5
# 4   114.225745                        78                           3
#
#    num_competitor_within_1km                      district  latitude_y  \
# 0                          4  Central and Western District    22.28219
# 1                         14                  Sham Shui Po    22.32989
# 2                         13                 Yau Tsim Mong    22.32105
# 3                         15                 Yau Tsim Mong    22.32105
# 4                          4                     Kwon Tong    22.31326
#
#    longitude_y     Total  Average household sie  Median income  latitude_x_y
# 0    114.14486   87700.0                    2.6        42000.0            12
# 1    114.16250  164700.0                    2.6        22000.0            21
# 2    114.17261  123600.0                    2.5        27900.0            21
# 3    114.17261  123600.0                    2.5        27900.0            21
# 4    114.22581  247400.0                    2.7        22200.0             8

# %%
merged1['cust_num'] = merged1['Total'] / merged1['shop_count_in_district']
merged1['spend_per_cust'] = merged1['Median income'] * 0.05 * 12
merged1['sales_volume'] = merged1['spend_per_cust'] * merged1['cust_num']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'shop_count_in_district'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 merged1['cust_num'] = merged1['Total'] / merged1['shop_count_in_district']
#       2 merged1['spend_per_cust'] = merged1['Median income'] * 0.05 * 12
#       3 merged1['sales_volume'] = merged1['spend_per_cust'] * merged1['cust_num']
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'shop_count_in_district'

# %%
import math
merged1['sales_volume'] = [math.log(x) for x in merged1['sales_volume']]

# %%
merged1.head()

# %%
import matplotlib.pyplot as plt
plt.hist(merged1['sales_volume'])

# %%
# import statsmodels.api as sm

# y = merged1['sales_volume']
# x = merged1[['num_bus_stops_within_1km','Total household in district','Median income']]

# model = sm.OLS(y,x).fit()
# print(model.summary())

# %%
import statsmodels.api as sm

y = merged1['sales_volume']
x = merged1[['num_bus_stops_within_1km','num_mtr_station_within_1km','num_competitor_within_1km']]

model = sm.OLS(y,x).fit()
print(model.summary())

# %%
merged1.to_csv('merged1.csv')

# %% [markdown]
# # adress_optimization

# %%
zoneAnalysis = pd.read_csv("data/processed1/zoneAnalysis.csv")
zoneAnalysis.head()

# %%
x_new = zoneAnalysis[['Number_of_busStop','Number_of_Mtr','Number_of_competitor']]
predict = model.predict(x_new)
zoneAnalysis['predicted_sales'] = predict

# %%
x1 = 1
zoneAnalysis['has_shop'] = [1 if i>0 else 0 for i in zoneAnalysis['Number_of_shop']]
zoneAnalysis['rent'] = zoneAnalysis['predicted_sales'] * 0.08 
zoneAnalysis['disposal'] = [math.log(300000) for i in zoneAnalysis['rent']] * zoneAnalysis['has_shop']
zoneAnalysis['cost_per_grid'] = (zoneAnalysis['disposal'] - zoneAnalysis['rent']) * x1

# %%
zoneAnalysis.head()

# %%
zoneAnalysis.to_csv('zoneAnalysis1111.csv')

# %%
total_sales = zoneAnalysis['predicted_sales'].sum()
total_cost = zoneAnalysis['cost_per_grid'].sum()
#total_revenue =

# %%
total_cost

# %%
from pulp import *

# Create a maximization problem
problem = LpProblem("example_mip", LpMaximize)

# Define variables
x = LpVariable('x', lowBound=0, cat='Integer')
y = LpVariable('y', lowBound=0, cat='Integer')

# Define objective function
problem += 2*x + 3*y

# Define constraints
problem += 4*x + 3*y <= 25
problem += x + y <= 8

# Print problem statement
print(problem)

# Solve the problem
status = problem.solve()

# Print the solution
print("Status:", LpStatus[status])
print("Optimal Solution:")
print("x =", value(x))
print("y =", value(y))
print("Objective Value =", value(problem.objective))
